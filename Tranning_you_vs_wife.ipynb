# %% [markdown]
# <a href="https://colab.research.google.com/github/taironeAlves/Machine-Learning-you-vs-wife/blob/main/Tranning_you_vs_wife.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rfv /tmp/ml
# Out:
# removed '/tmp/ml/README.md'
# removed '/tmp/ml/teste/wife/wife2.jpg'
# removed '/tmp/ml/teste/wife/wife.jpg'
# removed directory '/tmp/ml/teste/wife'
# removed '/tmp/ml/teste/you/you.jpg'
# removed '/tmp/ml/teste/you/you2.jpg'
# removed directory '/tmp/ml/teste/you'
# removed directory '/tmp/ml/teste'
# removed '/tmp/ml/LICENSE'
# removed '/tmp/ml/checks/wife2.jpg'
# removed '/tmp/ml/checks/you.jpg'
# removed '/tmp/ml/checks/wife.jpg'
# removed '/tmp/ml/checks/you2.jpg'
# removed directory '/tmp/ml/checks'
# removed '/tmp/ml/.git/logs/refs/heads/main'
# removed directory '/tmp/ml/.git/logs/refs/heads'
# removed '/tmp/ml/.git/logs/refs/remotes/origin/HEAD'
# removed directory '/tmp/ml/.git/logs/refs/remotes/origin'
# removed directory '/tmp/ml/.git/logs/refs/remotes'
# removed directory '/tmp/ml/.git/logs/refs'
# removed '/tmp/ml/.git/logs/HEAD'
# removed directory '/tmp/ml/.git/logs'
# removed '/tmp/ml/.git/config'
# removed '/tmp/ml/.git/refs/heads/main'
# ...

# %%
# !git clone https://github.com/taironeAlves/Machine-Learning-you-vs-wife.git /tmp/ml
# Out:
# Cloning into '/tmp/ml'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 70 (delta 6), reused 14 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (70/70), 2.35 MiB | 26.74 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# !cd /tmp/ml

# %%
#@title Importações
import pandas as pd
import numpy as np
import keras
import matplotlib.pyplot as plt

from keras.applications import MobileNet
from keras.layers import Dense, GlobalAveragePooling2D, Dropout
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.models import Model
from keras.applications.mobilenet import preprocess_input

# %%
#@title Carregar MobileNet base
base_model = MobileNet(weights='imagenet', include_top=False,input_shape=(224, 224, 3))
base_model.summary()
# Out:
# Model: "mobilenet_1.00_224"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_13 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 112, 112, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_bn (BatchNormalization)   │ (None, 112, 112, 32)   │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_relu (ReLU)               │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1 (DepthwiseConv2D)     │ (None, 112, 112, 32)   │           288 │
# ...

# %%
#@title Criar nova cabeça do modelo
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(50, activation='relu')(x)
x = Dropout(0.2)(x)
preds = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=preds)

# %%
#@title Congelar camadas iniciais
for layer in base_model.layers[:80]:
    layer.trainable = False

for layer in base_model.layers[80:]:
    layer.trainable = True

# %%
#@title Preparar data generators
batch_size = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.3,
    zoom_range=0.3,
    height_shift_range=0.2,
    width_shift_range=0.2,
    rotation_range=40,
    horizontal_flip=True,
    preprocessing_function=preprocess_input
)

test_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=preprocess_input
)

training_set = train_datagen.flow_from_directory(
    '/tmp/ml/images',
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='binary'
)

test_set = test_datagen.flow_from_directory(
    '/tmp/ml/teste',
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='binary'
)
# Out:
# Found 40 images belonging to 2 classes.
# Found 4 images belonging to 2 classes.

# %%
#@title Compilar modelo
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
#@title Treinamento
history = model.fit(
    training_set,
    steps_per_epoch=len(training_set),
    epochs=10,
    validation_data=test_set,
    validation_steps=len(test_set)
)
# Out:
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.5833 - loss: 0.7558 - val_accuracy: 0.5000 - val_loss: 0.7474
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 3s/step - accuracy: 0.4750 - loss: 0.8431 - val_accuracy: 0.5000 - val_loss: 0.7413
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.7750 - loss: 0.6303 - val_accuracy: 0.5000 - val_loss: 0.7366
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.5417 - loss: 0.6618 - val_accuracy: 0.5000 - val_loss: 0.7346
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.6083 - loss: 0.6782 - val_accuracy: 0.5000 - val_loss: 0.7337
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 706ms/step - accuracy: 0.5000 - loss: 0.7357 - val_accuracy: 0.5000 - val_loss: 0.7334
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 693ms/step - accuracy: 0.7021 - loss: 0.5996 - val_accuracy: 0.5000 - val_loss: 0.7334
# Epoch 8/10
# ...

# %%
#@title Salvar modelo treinado
model.save('my_model.keras')
print("Modelo salvo!")
# Out:
# Modelo salvo!

# %%
#img_path = "/tmp/ml/checks/you.jpg"
img_path = "/tmp/ml/checks/wife.jpg"

test_image = image.load_img(img_path, target_size=(224, 224))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)

test_image = preprocess_input(test_image)

result = model.predict(test_image)[0][0]

threshold = 0.5

prediction = "wife" if result > threshold else "you"

print(f"Raw model output: {result:.4f}")
print(f"Predicted: {prediction}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Raw model output: 0.7604
# Predicted: wife
